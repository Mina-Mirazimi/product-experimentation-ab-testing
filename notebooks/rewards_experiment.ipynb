# %% [markdown]
# # Rewards Feature A/B Test\nShould the company launch a new rewards feature?

# %%
from src.generate_experiment import generate_experiment\ndf = generate_experiment()\ndf.head()

# %% [markdown]
# ## Workflow\nRandomization diagnostics → primary metric → secondary metrics → guardrails → covariate adjustment → product decision.
